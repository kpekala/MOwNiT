# %% [markdown]
# # Mownit lab2

# %% [markdown]
# ### Import bibliotek

# %%
from math import exp, sin, cos, pi
import matplotlib.pyplot as plt

# %% [markdown]
# ### Moja wersja funkcji:

# %%
#f7, k=3, m=2, [-pi, 2pi]
def f(x):
    return exp(-3 * sin(2*x)) + 3 * cos(2*x)

# %%
x_start = -pi
x_end = 2*pi

# %% [markdown]
# ## Interpolacja Lagrange

# %%
def Chebyshev_node(k, n):
    return 0.5*(x_start + x_end) + 0.5*(x_end - x_start) * cos(pi * (2*k+1) * (1/(2*n)))
def even_node(i, n):
    return x_start + i * (x_end - x_start)/(n-1)

def build_xy_data(points_number, nodes_method):
    x_points = [0] * points_number
    y_points = [0] * points_number
    for i in range(points_number):
        x_points[i] = nodes_method(i, points_number)
        y_points[i] = f(x_points[i])
    return x_points, y_points

# %%
build_xy_data(3,Chebyshev_node)
# Out:
# ([5.651844896321887, 1.5707963267948968, -2.5102522427320926],
#  [18.34898564633229, -1.9999999999999991, 0.9671323793121457])

# %%
def eval_lagrange(xs, ys, x):
    n = len(xs)
    y_eval = 0
    for i in range(n):
        p = 1
        for j in range(n):
            if i != j:
                p *=  (x - xs[j])/(xs[i] - xs[j])

        y_eval += p * ys[i] 
    return y_eval

# %% [markdown]
# ### Proste testy

# %%
xs, ys = build_xy_data(30,Chebyshev_node)
x_e = 0
y_e = eval_lagrange(xs, ys, x_e)

# %%
plt.plot(xs,ys)
plt.plot(x_e,y_e,"or")

# %% [markdown]
# ### Wizualizacja interpolacji

# %%
def gen_points(int_fun, xs, ys, n):
    x_delta = (x_end - x_start)/(n-1)
    xt = []
    yt = []
    for i in range(n):
        x = x_start + i * x_delta
        xt.append(x)
        yt.append(int_fun(xs,ys,x))
    return xt, yt

# %%
def visualize(n):
    xs, ys = build_xy_data(n,Chebyshev_node)
    xt, yt = gen_points(eval_lagrange, xs, ys, 100)
    plt.plot(xt,yt)
    xp,yp = build_xy_data(100,even_node)
    plt.plot(xp,yp)

# %%
visualize(40)

# %%
def max_diff(n):
    xs, ys = build_xy_data(n,Chebyshev_node)
    xt, yt = gen_points(eval_lagrange, xs, ys, 100)
    xp, yp = build_xy_data(100,even_node)
    return max([(abs(yp[i]-yt[i]),xp[i]) for i in range(len(yp))])

# %%
max_diff(30)
# Out:
# (1.422184399019768, 1.9991953250116863)

# %%
visualize(30)
